# %%
import torch
import torch.nn as nn

from src.quadratic_annealing_optimizer import QuadraticAnnealingOptimizer
from src.models import QuadraticMLP
from src.utils import build_sampler, data_load_and_prep
from src.training import train
from src.newton_optimizer import NewtonOptimizer

EXPERIMENT_NAME = "optimizer-comparison-mlp-digits-q"

# %% [markdown]
# ## Loading sample Iris data for training

# %%
train_loader, test_loader = data_load_and_prep("digits", test_size=0.3, random_state=42, batch_size='full')
NUM_EPOCHS = 30
HIDDEN_SIZES = [32]

# %% [markdown]
# # Classical optimization for benchmarking

# %%
loss_fn = nn.CrossEntropyLoss()
adam_model = QuadraticMLP(64, HIDDEN_SIZES, 10)
classical_device = "cpu" 
adam_optimizer = torch.optim.Adam(adam_model.parameters(), 
                             lr=0.01,
                             betas=[0.9, 0.999],
                             )

# %% [markdown]
# ## Optimization using Adam optimizaer

# %%
train(
    model=adam_model,
    train_loader=train_loader,
    test_loader=test_loader,
    loss_fn=loss_fn,
    optimizer=adam_optimizer,
    c_device=classical_device,
    epochs=NUM_EPOCHS, 
    experiment_name = EXPERIMENT_NAME,
    run_name="adam-optimizer"
)
# Out:
# /home/filip/studia/master/second-order-by-annealer/venv/lib/python3.12/site-packages/mlflow/tracking/_tracking_service/utils.py:184: FutureWarning: The filesystem tracking backend (e.g., './mlruns') is deprecated as of February 2026. Consider transitioning to a database backend (e.g., 'sqlite:///mlflow.db') to take advantage of the latest MLflow features. See https://mlflow.org/docs/latest/self-hosting/migrate-from-file-store for migration guidance.
#   return FileStore(store_uri, store_uri)
# 2026/05/02 16:29:30 INFO mlflow.tracking.fluent: Experiment with name 'optimizer-comparison-mlp-digits-q' does not exist. Creating a new experiment.
# Epoch 000 | train_loss=2.0594 | train_acc=0.423 | test_loss=2.0569 | test_acc=0.430 |
# Epoch 005 | train_loss=1.1599 | train_acc=0.828 | test_loss=1.1788 | test_acc=0.813 |
# Epoch 010 | train_loss=0.6812 | train_acc=0.882 | test_loss=0.7181 | test_acc=0.857 |
# Epoch 015 | train_loss=0.4176 | train_acc=0.924 | test_loss=0.4643 | test_acc=0.900 |
# 2026/05/02 16:29:31 WARNING mlflow.pytorch: Saving pytorch model by Pickle or CloudPickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization.The recommended safe alternative is to set 'export_model' to True to save the pytorch model using the safe graph model format.
# Epoch 020 | train_loss=0.2726 | train_acc=0.951 | test_loss=0.3239 | test_acc=0.924 |
# Epoch 025 | train_loss=0.1922 | train_acc=0.963 | test_loss=0.2476 | test_acc=0.941 |
# Epoch 029 | train_loss=0.1516 | train_acc=0.971 | test_loss=0.2114 | test_acc=0.952 |
# {'run_id': '2c81cda629594adf9a9bfe088d17a146',
#  'experiment_id': '754943671724693117',
#  'experiment_name': 'optimizer-comparison-mlp-digits-q',
#  'tracking_uri': 'file:///home/filip/studia/master/second-order-by-annealer/mlruns',
#  'warm_start_epochs': 1,
#  'optimization_time_sec': 0.01660496199838235,
#  'raw_optimization_time_sec': 0.07803826099825528,
#  'sum_epoch_optimization_time_sec': 0.01660496199838235,
#  'train_evaluation_time_sec': 0.10939830099687242,
#  'test_evaluation_time_sec': 0.04778331800025626,
#  'evaluation_time_sec': 0.15718161899712868,
#  'training_time_sec': 0.5717402789996413,
#  'final_train_loss': 0.15158899128437042,
#  'final_test_loss': 0.21141202747821808,
#  'final_train_metric': 0.9705648369132857,
#  'final_test_metric': 0.9518518518518518,
#  'optimizer': 'Adam',
#  'seed': None,
#  'epochs_completed': 30,
#  'early_stopped': False,
#  'early_stop_reason': None,
#  'zero_acceptance_patience': 6,
#  'final_zero_acceptance_streak': 0}

# %% [markdown]
# ## Optimization using Adam optimizaer on cuda

# %%
loss_fn = nn.CrossEntropyLoss()
adam_model = QuadraticMLP(64, HIDDEN_SIZES, 10)
classical_device = "cuda" 
adam_optimizer = torch.optim.Adam(adam_model.parameters(), 
                             lr=0.01,
                             betas=[0.9, 0.999],
                             )

# %%
train(
    model=adam_model,
    train_loader=train_loader,
    test_loader=test_loader,
    loss_fn=loss_fn,
    optimizer=adam_optimizer,
    c_device=classical_device,
    epochs=NUM_EPOCHS, 
    experiment_name = EXPERIMENT_NAME,
    run_name="adam-optimizer-cuda"
)
# Out:
# Epoch 000 | train_loss=2.0258 | train_acc=0.374 | test_loss=2.0218 | test_acc=0.374 |
# Epoch 005 | train_loss=1.1557 | train_acc=0.821 | test_loss=1.1871 | test_acc=0.791 |
# Epoch 010 | train_loss=0.6767 | train_acc=0.885 | test_loss=0.7321 | test_acc=0.839 |
# Epoch 015 | train_loss=0.4054 | train_acc=0.932 | test_loss=0.4613 | test_acc=0.904 |
# Epoch 020 | train_loss=0.2653 | train_acc=0.954 | test_loss=0.3182 | test_acc=0.924 |
# Epoch 025 | train_loss=0.1884 | train_acc=0.967 | test_loss=0.2476 | test_acc=0.939 |
# 2026/05/02 16:29:41 WARNING mlflow.pytorch: Saving pytorch model by Pickle or CloudPickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization.The recommended safe alternative is to set 'export_model' to True to save the pytorch model using the safe graph model format.
# Epoch 029 | train_loss=0.1489 | train_acc=0.971 | test_loss=0.2149 | test_acc=0.939 |
# {'run_id': 'b112f35cf56743718ff69516a44172a6',
#  'experiment_id': '754943671724693117',
#  'experiment_name': 'optimizer-comparison-mlp-digits-q',
#  'tracking_uri': 'file:///home/filip/studia/master/second-order-by-annealer/mlruns',
#  'warm_start_epochs': 1,
#  'optimization_time_sec': 0.02652839799884532,
#  'raw_optimization_time_sec': 0.15016350999849237,
#  'sum_epoch_optimization_time_sec': 0.02652839799884532,
#  'train_evaluation_time_sec': 0.12757043200144835,
#  'test_evaluation_time_sec': 0.0503854010021314,
#  'evaluation_time_sec': 0.17795583300357976,
#  'training_time_sec': 0.6611549039998863,
#  'final_train_loss': 0.14887283742427826,
#  'final_test_loss': 0.21491283178329468,
#  'final_train_metric': 0.9713603818615751,
#  'final_test_metric': 0.9388888888888889,
#  'optimizer': 'Adam',
#  'seed': None,
#  'epochs_completed': 30,
#  'early_stopped': False,
#  'early_stop_reason': None,
#  'zero_acceptance_patience': 6,
#  'final_zero_acceptance_streak': 0}

# %% [markdown]
# ## Optimization using LBFGS-style second-order optimizer

# %%
loss_fn = nn.CrossEntropyLoss()
lbfgs_model = QuadraticMLP(64, HIDDEN_SIZES, 10)
classical_device = "cpu" 
lbfgs_optimizer = torch.optim.LBFGS(lbfgs_model.parameters(), 
                              lr=0.01,
                              max_iter=1,
                              history_size=100,
                              line_search_fn=None,
                              )

# %%
train(
    model=lbfgs_model,
    train_loader=train_loader,
    test_loader=test_loader,
    loss_fn=loss_fn,
    optimizer=lbfgs_optimizer,
    c_device=classical_device,
    epochs=NUM_EPOCHS,
    experiment_name = EXPERIMENT_NAME,
    run_name="lbfgs-optimizer"
)
# Out:
# Epoch 000 | train_loss=2.3294 | train_acc=0.068 | test_loss=2.3316 | test_acc=0.070 |
# Epoch 005 | train_loss=1.7756 | train_acc=0.684 | test_loss=1.7860 | test_acc=0.674 |
# Epoch 010 | train_loss=1.4712 | train_acc=0.818 | test_loss=1.4858 | test_acc=0.783 |
# Epoch 015 | train_loss=1.2184 | train_acc=0.870 | test_loss=1.2363 | test_acc=0.833 |
# Epoch 020 | train_loss=1.0237 | train_acc=0.897 | test_loss=1.0452 | test_acc=0.870 |
# Epoch 025 | train_loss=0.8675 | train_acc=0.916 | test_loss=0.8924 | test_acc=0.896 |
# Epoch 029 | train_loss=0.7580 | train_acc=0.932 | test_loss=0.7853 | test_acc=0.909 |
# 2026/05/02 16:30:26 WARNING mlflow.pytorch: Saving pytorch model by Pickle or CloudPickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization.The recommended safe alternative is to set 'export_model' to True to save the pytorch model using the safe graph model format.
# {'run_id': 'a0f17bee937b424f830860e8f18ff67f',
#  'experiment_id': '754943671724693117',
#  'experiment_name': 'optimizer-comparison-mlp-digits-q',
#  'tracking_uri': 'file:///home/filip/studia/master/second-order-by-annealer/mlruns',
#  'warm_start_epochs': 1,
#  'optimization_time_sec': 0.02087459199810837,
#  'raw_optimization_time_sec': 0.02216398299788125,
#  'sum_epoch_optimization_time_sec': 0.02087459199810837,
#  'train_evaluation_time_sec': 0.11588086000119802,
#  'test_evaluation_time_sec': 0.05426300399994943,
#  'evaluation_time_sec': 0.17014386400114745,
#  'training_time_sec': 0.3956016600004659,
#  'final_train_loss': 0.7580074667930603,
#  'final_test_loss': 0.7852705121040344,
#  'final_train_metric': 0.9315831344470963,
#  'final_test_metric': 0.9092592592592592,
#  'optimizer': 'LBFGS',
#  'seed': None,
#  'epochs_completed': 30,
#  'early_stopped': False,
#  'early_stop_reason': None,
#  'zero_acceptance_patience': 6,
#  'final_zero_acceptance_streak': 0}

# %% [markdown]
# ## Optimization using Newton-Rapson method

# %%
loss_fn = nn.CrossEntropyLoss() 
newton_model = QuadraticMLP(64, HIDDEN_SIZES, 10)
classical_device = "cpu"
newton_optimizer = NewtonOptimizer(newton_model.parameters(), 
                                   lr=1, 
                                   max_iter=1,
                                   damping=1e-4,
                                   )

# %%
train(
    model=newton_model,
    train_loader=train_loader,
    test_loader=test_loader,
    loss_fn=loss_fn,
    optimizer=newton_optimizer,
    c_device=classical_device,
    epochs=NUM_EPOCHS,
    experiment_name = EXPERIMENT_NAME,
    run_name="newton-optimizer"
)
# Out:
# Epoch 000 | train_loss=2.5341 | train_acc=0.113 | test_loss=2.5901 | test_acc=0.102 |
# Epoch 005 | train_loss=2799.6677 | train_acc=0.488 | test_loss=3028.7493 | test_acc=0.446 |
# Epoch 010 | train_loss=1340.1602 | train_acc=0.498 | test_loss=1655.2322 | test_acc=0.454 |
# Epoch 015 | train_loss=918.4567 | train_acc=0.547 | test_loss=1287.2007 | test_acc=0.476 |
# Epoch 020 | train_loss=949.1610 | train_acc=0.516 | test_loss=1169.8824 | test_acc=0.483 |
# Epoch 025 | train_loss=1159.3243 | train_acc=0.480 | test_loss=1422.3171 | test_acc=0.454 |
# 2026/05/02 16:31:14 WARNING mlflow.pytorch: Saving pytorch model by Pickle or CloudPickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization.The recommended safe alternative is to set 'export_model' to True to save the pytorch model using the safe graph model format.
# Epoch 029 | train_loss=961.6927 | train_acc=0.526 | test_loss=1214.0101 | test_acc=0.476 |
# {'run_id': '762e59e827ea49328b9ccbc1d048b531',
#  'experiment_id': '754943671724693117',
#  'experiment_name': 'optimizer-comparison-mlp-digits-q',
#  'tracking_uri': 'file:///home/filip/studia/master/second-order-by-annealer/mlruns',
#  'warm_start_epochs': 1,
#  'optimization_time_sec': 40.006382429998666,
#  'raw_optimization_time_sec': 41.336080340998706,
#  'sum_epoch_optimization_time_sec': 40.006382429998666,
#  'train_evaluation_time_sec': 0.2949242619997676,
#  'test_evaluation_time_sec': 0.0581824080009028,
#  'evaluation_time_sec': 0.3531066700006704,
#  'training_time_sec': 41.91600611700051,
#  'final_train_loss': 961.6927490234375,
#  'final_test_loss': 1214.0101318359375,
#  'final_train_metric': 0.5258552108194113,
#  'final_test_metric': 0.4759259259259259,
#  'optimizer': 'NewtonOptimizer',
#  'seed': None,
#  'epochs_completed': 30,
#  'early_stopped': False,
#  'early_stop_reason': None,
#  'zero_acceptance_patience': 6,
#  'final_zero_acceptance_streak': 0}

# %% [markdown]
# ## Optimization using Quadratic Annealer (cpu + momentum)

# %%
loss_fn = nn.CrossEntropyLoss()
model = QuadraticMLP(64, HIDDEN_SIZES, 10)
classical_device = "cpu" 
        
sampler = build_sampler(mode="simulated")

optimizer = QuadraticAnnealingOptimizer(
    sampler=sampler,
    model=model,
    device="cpu",
    subset_size=48,
    step_size=0.05,
    num_reads=100,
    beta=0.9,
)

# %%
train(
    model=model,
    train_loader=train_loader,
    test_loader=test_loader,
    loss_fn=loss_fn,
    optimizer=optimizer,
    c_device=classical_device,
    epochs=NUM_EPOCHS,
    experiment_name = EXPERIMENT_NAME,
    run_name="quadratic-annealer-optimizer-48"
)
# Out:
# Epoch 000 | train_loss=2.2705 | train_acc=0.148 | test_loss=2.2330 | test_acc=0.183 |
# Epoch 005 | train_loss=1.1578 | train_acc=0.749 | test_loss=1.1528 | test_acc=0.739 |
# Epoch 010 | train_loss=0.4636 | train_acc=0.926 | test_loss=0.4846 | test_acc=0.915 |
# Epoch 015 | train_loss=0.2386 | train_acc=0.958 | test_loss=0.2890 | test_acc=0.944 |
# Epoch 020 | train_loss=0.1487 | train_acc=0.974 | test_loss=0.2321 | test_acc=0.943 |
# Epoch 025 | train_loss=0.0934 | train_acc=0.989 | test_loss=0.1962 | test_acc=0.946 |
# 2026/05/02 17:09:57 WARNING mlflow.pytorch: Saving pytorch model by Pickle or CloudPickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization.The recommended safe alternative is to set 'export_model' to True to save the pytorch model using the safe graph model format.
# Epoch 029 | train_loss=0.0690 | train_acc=0.993 | test_loss=0.1717 | test_acc=0.950 |
# {'run_id': 'f2308fb0ed244ace912768d5a79060ef',
#  'experiment_id': '754943671724693117',
#  'experiment_name': 'optimizer-comparison-mlp-digits-q',
#  'tracking_uri': 'file:///home/filip/studia/master/second-order-by-annealer/mlruns',
#  'warm_start_epochs': 1,
#  'optimization_time_sec': 2.3414951269933226,
#  'raw_optimization_time_sec': 2.4069857109934674,
#  'sum_epoch_optimization_time_sec': 2.3414951269933226,
#  'train_evaluation_time_sec': 0.12397554499511898,
#  'test_evaluation_time_sec': 0.06227322099766752,
#  'evaluation_time_sec': 0.1862487659927865,
#  'training_time_sec': 2.896738639999967,
#  'final_train_loss': 0.06897834688425064,
#  'final_test_loss': 0.17174658179283142,
#  'final_train_metric': 0.9928400954653938,
#  'final_test_metric': 0.95,
#  'optimizer': 'QuadraticAnnealingOptimizer',
#  'seed': None,
#  'epochs_completed': 30,
#  'early_stopped': False,
#  'early_stop_reason': None,
#  'zero_acceptance_patience': 6,
#  'final_zero_acceptance_streak': 0}

# %% [markdown]
# ## Optimization using Quadratic Annealer (D-Wave + momentum)

# %%
loss_fn = nn.CrossEntropyLoss()
model = QuadraticMLP(64, HIDDEN_SIZES, 10)
classical_device = "cpu" 

sampler = build_sampler(mode="dwave")

optimizer = QuadraticAnnealingOptimizer(
    sampler=sampler,
    model=model,
    device="cpu",
    subset_size=48,
    step_size=0.05,
    num_reads=100,
    beta=0.9,
)

# %%
train(
    model=model,
    train_loader=train_loader,
    test_loader=test_loader,
    loss_fn=loss_fn,
    optimizer=optimizer,
    c_device=classical_device,
    epochs=NUM_EPOCHS,
    experiment_name = EXPERIMENT_NAME,
    run_name="quadratic-annealer-dwave-optimizer-48"
)
# Out:
# Epoch 000 | train_loss=2.2127 | train_acc=0.188 | test_loss=2.2024 | test_acc=0.222 |
# Epoch 005 | train_loss=1.1872 | train_acc=0.745 | test_loss=1.1898 | test_acc=0.733 |
# Epoch 010 | train_loss=0.5196 | train_acc=0.919 | test_loss=0.5463 | test_acc=0.894 |
# Epoch 015 | train_loss=0.2504 | train_acc=0.959 | test_loss=0.3157 | test_acc=0.941 |
# Epoch 020 | train_loss=0.1507 | train_acc=0.977 | test_loss=0.2407 | test_acc=0.946 |
# Epoch 025 | train_loss=0.1413 | train_acc=0.976 | test_loss=0.2475 | test_acc=0.946 |
# 2026/05/02 17:11:03 WARNING mlflow.pytorch: Saving pytorch model by Pickle or CloudPickle format requires exercising caution because these formats rely on Python's object serialization mechanism, which can execute arbitrary code during deserialization.The recommended safe alternative is to set 'export_model' to True to save the pytorch model using the safe graph model format.
# {'run_id': '2fd075f7cd6f4d1cbec26f8b54da240d',
#  'experiment_id': '754943671724693117',
#  'experiment_name': 'optimizer-comparison-mlp-digits-q',
#  'tracking_uri': 'file:///home/filip/studia/master/second-order-by-annealer/mlruns',
#  'warm_start_epochs': 1,
#  'optimization_time_sec': 1.5189549409969914,
#  'raw_optimization_time_sec': 7.374695833994338,
#  'sum_epoch_optimization_time_sec': 1.5189549409969914,
#  'train_evaluation_time_sec': 0.13435647299775155,
#  'test_evaluation_time_sec': 0.06991397599813354,
#  'evaluation_time_sec': 0.2042704489958851,
#  'training_time_sec': 31.359422720999646,
#  'final_train_loss': 0.14134465157985687,
#  'final_test_loss': 0.247547909617424,
#  'final_train_metric': 0.9761336515513126,
#  'final_test_metric': 0.9462962962962963,
#  'optimizer': 'QuadraticAnnealingOptimizer',
#  'seed': None,
#  'epochs_completed': 28,
#  'early_stopped': True,
#  'early_stop_reason': 'acceptance_rate_was_zero_for_6_consecutive_epochs',
#  'zero_acceptance_patience': 6,
#  'final_zero_acceptance_streak': 6}
